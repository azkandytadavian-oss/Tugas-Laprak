# %%
print("Nama : Azkandyta Davian Nusa Satrya") #ini perintah untuk menampilkan Nama
print("NIM : 2605060066") #ini perintah untuk menampilkan NIM
print("Tempat, Tanggal Lahir : Brebes, 16 Agustus 2008") #ini perintah untuk menampilkan Tempat, Tanggal Lahir
print("Jenis Kelamin : Laki-Laki") #ini perintah untuk menampilkan Jenis Kelamin
print("Hobi : Futsal dan Menonton Film") #ini perintah untuk menampilkan Hobi
# Out:
# Nama : Azkandyta Davian Nusa Satrya
# NIM : 2605060066
# Tempat, Tanggal Lahir : Brebes, 16 Agustus 2008
# Jenis Kelamin : Laki-Laki
# Hobi : Futsal dan Menonton Film
